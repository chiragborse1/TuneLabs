# %% [markdown]
# <a href="https://colab.research.google.com/github/tunelabsai/tunelabs/blob/main/studio/TuneLabs_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://tunelabs.ai/"><img src="https://github.com/tunelabsai/tunelabs/raw/main/images/tunelabs%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/tunelabs"><img src="https://github.com/tunelabsai/tunelabs/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://tunelabs.ai/docs/"><img src="https://github.com/tunelabsai/tunelabs/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/tunelabsai/tunelabs">Github</a> </i> ⭐
# </div>
#
# To install TuneLabs Studio on your local device, follow [our guide](https://tunelabs.ai/docs/new/tunelabs-studio/install). TuneLabs Studio is licensed [AGPL-3.0](https://github.com/tunelabsai/tunelabs/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### TuneLabs Studio
#
# Train and run open models with [**TuneLabs Studio**](https://tunelabs.ai/docs/new/tunelabs-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making TuneLabs Studio install on Colab T4 GPUs faster.
#
# [Features](https://tunelabs.ai/docs/new/tunelabs-studio#features) • [Quickstart](https://tunelabs.ai/docs/new/tunelabs-studio/start) • [Data Recipes](https://tunelabs.ai/docs/new/tunelabs-studio/data-recipe) • [Studio Chat](https://tunelabs.ai/docs/new/tunelabs-studio/chat) • [Export](https://tunelabs.ai/docs/new/tunelabs-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/tunelabsai/tunelabs/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/tunelabsai/tunelabs.git
# %cd /content/tunelabs
# !chmod +x studio/setup.sh && ./studio/setup.sh --local

# %% [markdown]
# ### Start TuneLabs Studio

# %%
import sys
sys.path.insert(0, "/content/tunelabs/studio/backend")
from colab import start
start()

# %% [markdown]
# And we're done! If you have any questions on TuneLabs, we have a [Discord](https://discord.gg/tunelabs) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use TuneLabs locally? Read our [Installation Guide](https://tunelabs.ai/docs/get-started/install) for details on installing TuneLabs on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://tunelabs.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://tunelabs.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://tunelabs.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://tunelabs.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://tunelabs.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://tunelabs.ai"><img src="https://github.com/tunelabsai/tunelabs/raw/main/images/tunelabs%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/tunelabs"><img src="https://github.com/tunelabsai/tunelabs/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://tunelabs.ai/docs/"><img src="https://github.com/tunelabsai/tunelabs/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/tunelabsai/tunelabs">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/tunelabsai/tunelabs/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
